# %%
import glob
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
file_path = glob.glob('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/110mW_5sec_50rep_cell??/delta.tif')
file_path.sort()

# %%
line_profile = 0

#体裁調整
fig = plt.figure(figsize = (6, 6))
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['xtick.major.width'] = 1.0
plt.rcParams['ytick.major.width'] = 1.0
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams["font.size"] = 20
    
for path in file_path:
    

    #加熱中心の強度変化
    delta_image = np.array(Image.open(path))
    xaxis = np.arange(0, 15, 61.75/64)
    line_profile += delta_image[21:37, 31]
    plt.plot(xaxis, delta_image[21:37, 31], marker = 'o', markersize = 7, linewidth = 1, color = 'skyblue')
plt.plot(xaxis, line_profile/len(file_path), marker = 'o', markersize = 10, linewidth = 3, color = 'blue')
plt.ylim(-1, 5)
plt.xlim(-0.5, 15)

pp = PdfPages('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/Line_Profile/5sec.pdf')
pp.savefig(fig)
pp.close()

plt.show()

# %%
file_path = glob.glob('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/150mW_1sec_50rep_cell??/delta.tif')
file_path.sort()

# %%
line_profile = 0

#体裁調整
fig = plt.figure(figsize = (6, 6))
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['xtick.major.width'] = 1.0
plt.rcParams['ytick.major.width'] = 1.0
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams["font.size"] = 20
    
for path in file_path:
    

    #加熱中心の強度変化
    delta_image = np.array(Image.open(path))
    xaxis = np.arange(0, 15, 61.75/64)
    line_profile += delta_image[21:37, 31]
    plt.plot(xaxis, delta_image[21:37, 31], marker = 'o', markersize = 7, linewidth = 1, color = 'lightpink')
plt.plot(xaxis, line_profile/len(file_path), marker = 'o', markersize = 10, linewidth = 3, color = 'red')
plt.ylim(-1, 5)
plt.xlim(-0.5, 15)

pp = PdfPages('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/Line_Profile/1sec.pdf')
pp.savefig(fig)
pp.close()

plt.show()

# %%
'''
for path in file_path:
    plt.figure(figsize = (6, 6))
    #加熱中心の強度変化
    delta_image = np.array(Image.open(path))
    delta_image_ = delta_image
    delta_image_[24:33, 30] = 0
    plt.imshow(delta_image_, vmin = 0, vmax = 3)
    plt.show()
'''
# Out:
# '\nfor path in file_path:\n    plt.figure(figsize = (6, 6))\n    #加熱中心の強度変化\n    delta_image = np.array(Image.open(path))\n    delta_image_ = delta_image\n    delta_image_[24:33, 30] = 0\n    plt.imshow(delta_image_, vmin = 0, vmax = 3)\n    plt.show()\n'

# %%
file_path = glob.glob('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/160mW_0.5sec_50rep_cell??/delta.tif')
file_path.sort()

# %%
line_profile = 0

#体裁調整
fig = plt.figure(figsize = (6, 6))
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['xtick.major.width'] = 1.0
plt.rcParams['ytick.major.width'] = 1.0
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams["font.size"] = 20
    
for path in file_path:
    

    #加熱中心の強度変化
    delta_image = np.array(Image.open(path))
    xaxis = np.arange(0, 15, 61.75/64)
    line_profile += delta_image[21:37, 31]
    plt.plot(xaxis, delta_image[21:37, 31], marker = 'o', markersize = 7, linewidth = 1, color = 'lightgrey')
plt.plot(xaxis, line_profile/len(file_path), marker = 'o', markersize = 10, linewidth = 3, color = 'black')
plt.ylim(-1, 5)
plt.xlim(-0.5, 15)

pp = PdfPages('/Users/masaharu/Desktop/執筆論文/温度ダイナミクス論文/Fig4/Fig4b/Line_Profile/0.5sec.pdf')
pp.savefig(fig)
pp.close()

plt.show()

# %%
'''
for path in file_path:
    plt.figure(figsize = (6, 6))
    #加熱中心の強度変化
    delta_image = np.array(Image.open(path))
    delta_image_ = delta_image
    delta_image_[24:33, 30] = 0
    plt.imshow(delta_image_, vmin = 0, vmax = 3)
    plt.show()
'''
# Out:
# '\nfor path in file_path:\n    plt.figure(figsize = (6, 6))\n    #加熱中心の強度変化\n    delta_image = np.array(Image.open(path))\n    delta_image_ = delta_image\n    delta_image_[24:33, 30] = 0\n    plt.imshow(delta_image_, vmin = 0, vmax = 3)\n    plt.show()\n'
